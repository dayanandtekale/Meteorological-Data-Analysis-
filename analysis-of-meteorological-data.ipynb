# %% [markdown]
# # Meterological Data Analysis

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Objective:
#
# #### The Meteorological Dataset Consists of:
#
# * Total Number of Data Point: 96453
# * Total Number of Attribute/Columns in data set is 12.
#
# #### Attribute Information:
#
# 1. Formatted Date
# 2. Summary
# 3. Precip Type
# 4. Temperature (C)
# 5. Apparent Temperature (C)
# 6. Humidity
# 7. Wind Speed (km/h)
# 8. Wind Bearing (degrees)
# 9. Visibility (km)
# 10. Loud Cover
# 11. Pressure (millibars)
# 12. Daily Summary

# %% [markdown]
# ## Loading the Data

# %%
#Python Library 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#Reading weatherHistory.csv file
df = pd.read_csv("weatherHistory.csv")
df.head(10)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
# 6                  5.522222      0.95            12.3648
# 7                  6.527778      0.89            14.1519
# 8                 10.822222      0.82            11.3183
# 9                 13.772222      0.72            12.5258
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
# 5                   258.0          14.9569         0.0               1016.66
# 6                   259.0           9.9820         0.0               1016.72
# 7                   260.0           9.9820         0.0               1016.84
# 8                   259.0           9.9820         0.0               1017.37
# 9                   279.0           9.9820         0.0               1017.22
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# 5  Partly cloudy throughout the day.
# 6  Partly cloudy throughout the day.
# 7  Partly cloudy throughout the day.
# 8  Partly cloudy throughout the day.
# 9  Partly cloudy throughout the day.

# %%
#shape of Dataset
df.shape
# Out:
# (96453, 12)

# %%
#Statistical Summary of DataFrame
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
#Concise Summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
#Missing Values on Dataset from String to Date Time

df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %% [markdown]
# #### Observation:
#
# * In 'Precip Type' Column there are 517 missing values.
# * 'Wind Bearing (degrees)' has only integer values and Formatted Date is in String.
# * Minimum values of Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km) are Zero and they can be Zero.

# %%
#Changing Formatted Date from String to Datetime

df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc=True)

# %%
#Now Formatted Date is in Date Time Format

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 8.8+ MB

# %%
df.sample(20)
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 70285 2014-04-14 11:00:00+00:00  Mostly Cloudy        rain        18.838889
# 38229 2010-01-19 20:00:00+00:00       Overcast        snow        -1.622222
# 77289 2014-11-30 12:00:00+00:00          Foggy        rain         3.900000
# 71771 2014-12-15 10:00:00+00:00       Overcast        rain         7.222222
# 47084 2011-01-22 19:00:00+00:00       Overcast        snow        -0.094444
# 48265 2011-06-10 23:00:00+00:00  Mostly Cloudy        rain        17.644444
# 30506               1017.44             Partly cloudy starting in the morning.
# 23106               1006.03             Partly cloudy starting in the morning.
# 482                 1009.90                  Mostly cloudy throughout the day.
# 27073               1018.00                  Mostly cloudy throughout the day.
# 18370               1012.34  Partly cloudy starting overnight continuing un...
# 88012               1017.88             Partly cloudy starting in the morning.
# 85197               1007.31                       Overcast throughout the day.
# 4736                1014.24                  Partly cloudy throughout the day.
# 17668               1018.25           Partly cloudy starting in the afternoon.
# 10965               1011.21  Foggy starting in the morning continuing until...
# 6637                1025.53                  Mostly cloudy starting overnight.
# 40882               1023.61                  Partly cloudy throughout the day.

# %%
#Checking Wheather this dataset has Duplicate Values or not
sum(df.duplicated())
# Out:
# 24

# %% [markdown]
# # Explortary Data Analysis(EDA):
# ## Data Cleaning

# %%
#Number of Distinct Observation 
df.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
#DataFrame for Duplicate Values
df_duplicated = df[df.duplicated()]
df_duplicated
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 36072 2010-08-01 22:00:00+00:00          Clear        rain        18.800000
# 36073 2010-08-01 23:00:00+00:00          Clear        rain        18.222222
# 36074 2010-08-02 00:00:00+00:00          Clear        rain        18.072222
# 36075 2010-08-02 01:00:00+00:00          Clear        rain        16.622222
# 36076 2010-08-02 02:00:00+00:00          Clear        rain        16.094444
# 36077 2010-08-02 03:00:00+00:00          Clear        rain        15.955556
# 36078 2010-08-02 04:00:00+00:00          Clear        rain        17.088889
# 36079 2010-08-02 05:00:00+00:00          Clear        rain        20.822222
# 36080 2010-08-02 06:00:00+00:00          Clear        rain        23.405556
# 36081 2010-08-02 07:00:00+00:00          Clear        rain        26.050000
# 36082 2010-08-02 08:00:00+00:00          Clear        rain        27.688889
# 36083 2010-08-02 09:00:00+00:00          Clear        rain        28.561111
# 36084 2010-08-02 10:00:00+00:00          Clear        rain        28.816667
# 36085 2010-08-02 11:00:00+00:00  Partly Cloudy        rain        28.866667
# 36086 2010-08-02 12:00:00+00:00  Partly Cloudy        rain        29.827778
# 36087 2010-08-02 13:00:00+00:00  Partly Cloudy        rain        30.072222
# 36088 2010-08-02 14:00:00+00:00  Partly Cloudy        rain        31.066667
# 36089 2010-08-02 15:00:00+00:00  Partly Cloudy        rain        30.861111
# 36090 2010-08-02 16:00:00+00:00  Partly Cloudy        rain        29.950000
# 36091 2010-08-02 17:00:00+00:00          Clear        rain        28.811111
# 36092 2010-08-02 18:00:00+00:00          Clear        rain        25.250000
# 36093 2010-08-02 19:00:00+00:00          Clear        rain        22.172222
# 36094 2010-08-02 20:00:00+00:00  Partly Cloudy        rain        21.061111
# 36095 2010-08-02 21:00:00+00:00          Clear        rain        20.255556
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
#
# 52693                   221.0          11.1090         0.0
# 52695                   238.0          11.1573         0.0
# 52696                   258.0          11.1573         0.0
# 52698                   287.0          11.1573         0.0
# 52699                   286.0          11.1573         0.0
# 52701                   305.0          11.5920         0.0
# 52702                   112.0          16.1000         0.0
# 52704                   131.0          16.1000         0.0
# 52705                   162.0          16.1000         0.0
#
#        Pressure (millibars)                      Daily Summary
# 52672               1002.40         Mostly cloudy until night.
# 52674               1001.79         Mostly cloudy until night.
# 52675               1001.60         Mostly cloudy until night.
# 52677               1001.92         Mostly cloudy until night.
# 52678               1002.20         Mostly cloudy until night.
# 52680               1002.25         Light rain in the morning.
# 52681               1002.05         Light rain in the morning.
# 52683               1001.42         Light rain in the morning.
# 52684               1001.11         Light rain in the morning.
# 52687               1001.22         Light rain in the morning.
# 52692               1002.61         Light rain in the morning.
# 52693               1002.67         Light rain in the morning.
# 52695               1002.65         Light rain in the morning.
# 52696               1002.91         Light rain in the morning.
# 52698               1003.79         Light rain in the morning.
# 52699               1004.83         Light rain in the morning.
# 52701               1006.85         Light rain in the morning.
# 52702               1006.81         Light rain in the morning.
# 52704               1006.68  Mostly cloudy throughout the day.
# 52705               1007.08  Mostly cloudy throughout the day.

# %%
df_null.tail(20)
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 95569 2016-10-31 03:00:00+00:00          Clear         NaN         1.905556
# 95570 2016-10-31 04:00:00+00:00          Clear         NaN         1.894444
# 95571 2016-10-31 05:00:00+00:00          Clear         NaN         1.983333
# 95572 2016-10-31 06:00:00+00:00          Clear         NaN         2.494444
# 95573 2016-10-31 07:00:00+00:00          Clear         NaN         3.766667
# 95574 2016-10-31 08:00:00+00:00          Clear         NaN         5.688889
# 95575 2016-10-31 09:00:00+00:00          Clear         NaN         7.688889
# 95576 2016-10-31 10:00:00+00:00          Clear         NaN         9.594444
# 95577 2016-10-31 11:00:00+00:00          Clear         NaN        11.494444
# 95578 2016-10-31 12:00:00+00:00          Clear         NaN        12.766667
# 95579 2016-10-31 13:00:00+00:00  Partly Cloudy         NaN        13.022222
# 95580 2016-10-31 14:00:00+00:00  Partly Cloudy         NaN        12.538889
# 95581 2016-10-31 15:00:00+00:00  Mostly Cloudy         NaN        11.755556
# 95582 2016-10-31 16:00:00+00:00  Mostly Cloudy         NaN        10.688889
# 95583 2016-10-31 17:00:00+00:00  Mostly Cloudy         NaN         9.394444
# 95584 2016-10-31 18:00:00+00:00  Mostly Cloudy         NaN         8.322222
# 95585 2016-10-31 19:00:00+00:00  Mostly Cloudy         NaN         7.627778
# 95586 2016-10-31 20:00:00+00:00  Mostly Cloudy         NaN         7.111111
# 95587 2016-10-31 21:00:00+00:00  Partly Cloudy         NaN         6.672222
# 95588 2016-10-31 22:00:00+00:00  Mostly Cloudy         NaN         6.322222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 95569                  1.905556      0.88             4.7656
# 95570                  0.088889      0.89             6.2146
# 95571                 -0.133333      0.91             7.1645
# 95572                  0.227778      0.90             7.9373
# 95573                  1.561111      0.86             8.5169
# 95574                  3.783333      0.80             8.7262
# 95575                  6.177778      0.75             8.5813
# 95576                  7.972222      0.71            11.1251
# 95577                 11.494444      0.69            14.0553
# 95578                 12.766667      0.67            22.5400
# 95579                 13.022222      0.68            14.1680
# 95580                 12.538889      0.71            10.9641
# 95581                 11.755556      0.74             8.3237
# 95582                 10.688889      0.78             7.5187
# 95583                  8.377778      0.82             7.6797
# 95584                  7.044444      0.85             8.0339
# 95585                  6.183333      0.87             8.2271
# 95586                  5.511111      0.89             8.5008
# 95587                  4.961111      0.90             8.6457
# 95588                  4.588889      0.91             8.4686
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 95569                   246.0              0.0         0.0
# 95570                   245.0              0.0         0.0
# 95571                   252.0              0.0         0.0
# 95572                   258.0              0.0         0.0
# 95573                   258.0              0.0         0.0
# 95574                   259.0              0.0         0.0
# 95575                   264.0              0.0         0.0
# 95576                   276.0              0.0         0.0
# 95577                   284.0              0.0         0.0
# 95578                   286.0              0.0         0.0
# 95579                   291.0              0.0         0.0
# 95580                   293.0              0.0         0.0
# 95581                   294.0              0.0         0.0
# 95582                   293.0              0.0         0.0
# 95583                   290.0              0.0         0.0
# 95584                   290.0              0.0         0.0
# 95585                   293.0              0.0         0.0
# 95586                   297.0              0.0         0.0
# 95587                   299.0              0.0         0.0
# 95588                   299.0              0.0         0.0
#
#        Pressure (millibars)                             Daily Summary
# 95569               1024.98  Mostly cloudy starting in the afternoon.
# 95570               1024.84  Mostly cloudy starting in the afternoon.
# 95571               1024.81  Mostly cloudy starting in the afternoon.
# 95572               1024.76  Mostly cloudy starting in the afternoon.
# 95573               1024.65  Mostly cloudy starting in the afternoon.
# 95574               1024.48  Mostly cloudy starting in the afternoon.
# 95575               1024.20  Mostly cloudy starting in the afternoon.
# 95576               1023.70  Mostly cloudy starting in the afternoon.
# 95577               1023.06  Mostly cloudy starting in the afternoon.
# 95578               1022.49  Mostly cloudy starting in the afternoon.
# 95579               1022.12  Mostly cloudy starting in the afternoon.
# 95580               1021.90  Mostly cloudy starting in the afternoon.
# 95581               1021.75  Mostly cloudy starting in the afternoon.
# 95582               1021.69  Mostly cloudy starting in the afternoon.
# 95583               1021.70  Mostly cloudy starting in the afternoon.
# 95584               1021.73  Mostly cloudy starting in the afternoon.
# 95585               1021.76  Mostly cloudy starting in the afternoon.
# 95586               1021.81  Mostly cloudy starting in the afternoon.
# 95587               1021.83  Mostly cloudy starting in the afternoon.
# 95588               1021.80  Mostly cloudy starting in the afternoon.

# %%
#Droping NaN(Not a Number)
df_target = df.dropna()
df_target.shape
# Out:
# (95936, 12)

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95936 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            95936 non-null  datetime64[ns, UTC]
#  1   Summary                   95936 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           95936 non-null  float64
#  4   Apparent Temperature (C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind Speed (km/h)         95936 non-null  float64
#  7   Wind Bearing (degrees)    95936 non-null  float64
#  8   Visibility (km)           95936 non-null  float64
#  9   Loud Cover                95936 non-null  float64
#  10  Pressure (millibars)      95936 non-null  float64
#  11  Daily Summary             95936 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 9.5+ MB

# %%
df_target.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df_target = df_target.set_index("Formatted Date")
df_target
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                                  ...         ...              ...
# 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
# 2006-04-01 00:00:00+00:00                  9.377778      0.89
# 2006-04-01 01:00:00+00:00                  5.944444      0.83
# 2006-04-01 02:00:00+00:00                  6.977778      0.83
# ...                                             ...       ...
# 2016-09-09 17:00:00+00:00                 26.016667      0.43
# 2016-09-09 18:00:00+00:00                 24.583333      0.48
# 2016-09-09 19:00:00+00:00                 22.038889      0.56
# 2016-09-09 20:00:00+00:00                 21.522222      0.60
# 2016-09-09 21:00:00+00:00                 20.438889      0.61
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00            14.1197                   251.0
# 2006-03-31 23:00:00+00:00            14.2646                   259.0
# 2006-04-01 00:00:00+00:00             3.9284                   204.0
# 2006-04-01 01:00:00+00:00            14.1036                   269.0
# 2006-04-01 02:00:00+00:00            11.0446                   259.0
# ...                                      ...                     ...
# 2016-09-09 17:00:00+00:00            10.9963                    31.0
# 2016-09-09 18:00:00+00:00            10.0947                    20.0
# 2016-09-09 19:00:00+00:00             8.9838                    30.0
# 2016-09-09 20:00:00+00:00            10.5294                    20.0
# 2016-09-09 21:00:00+00:00             5.8765                    39.0
#
#                            Visibility (km)  Loud Cover  Pressure (millibars)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00          15.8263         0.0               1015.13
# 2006-03-31 23:00:00+00:00          15.8263         0.0               1015.63
# 2006-04-01 00:00:00+00:00          14.9569         0.0               1015.94
# 2006-04-01 01:00:00+00:00          15.8263         0.0               1016.41
# 2006-04-01 02:00:00+00:00          15.8263         0.0               1016.51
# ...                                    ...         ...                   ...
# 2016-09-09 17:00:00+00:00          16.1000         0.0               1014.36
# 2016-09-09 18:00:00+00:00          15.5526         0.0               1015.16
# 2016-09-09 19:00:00+00:00          16.1000         0.0               1015.66
# 2016-09-09 20:00:00+00:00          16.1000         0.0               1015.95
# 2016-09-09 21:00:00+00:00          15.5204         0.0               1016.16
#
#                                                     Daily Summary
# Formatted Date
# 2006-03-31 22:00:00+00:00       Partly cloudy throughout the day.
# 2006-03-31 23:00:00+00:00       Partly cloudy throughout the day.
# 2006-04-01 00:00:00+00:00       Partly cloudy throughout the day.
# 2006-04-01 01:00:00+00:00       Partly cloudy throughout the day.
# 2006-04-01 02:00:00+00:00       Partly cloudy throughout the day.
# ...                                                           ...
# 2016-09-09 17:00:00+00:00  Partly cloudy starting in the morning.
# 2016-09-09 18:00:00+00:00  Partly cloudy starting in the morning.
# 2016-09-09 19:00:00+00:00  Partly cloudy starting in the morning.
# 2016-09-09 20:00:00+00:00  Partly cloudy starting in the morning.
# 2016-09-09 21:00:00+00:00  Partly cloudy starting in the morning.
#
# [95936 rows x 11 columns]

# %% [markdown]
# **Given**:
#
# The Null Hypothesis H0 is **"*Has the Apparent temperature and humidity compared monthly across 10 years of the data indicate an increase due to Global warming*".**
#
# The Alternative Hypothesis H1 is **"*Has the Apparent temperature and humidity compared monthly across 10 years of the data not indicate an increase due to Global warming*".**

# %%
#Creating new DataFrame only for Apparent Temperature and Humidity
df_column = ['Apparent Temperature (C)', 'Humidity']
df_monthly_mean = df_target[df_column].resample("MS").mean() #MS-Month Starting
df_monthly_mean.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df_monthly_mean, height=8).map(plt.scatter, "Apparent Temperature (C)", "Humidity")
plt.show()

# %% [markdown]
# #### Observation:
#
# * There can be or may be Linear Relationship between "Humidity" and "Apparent Temperature (C)" with negative slope.

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data = df_monthly_mean)
plt.show()

# %% [markdown]
# #### Observation:
#
# * "Humidity" is remain constant from 2006 - 2016
# * But "Apparent Temperature (C)" is frequently changes from 2006 - 2016

# %% [markdown]
# ### 2D Scatter Plot with Color Coding for each Summary type

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df_target, hue="Summary", height=8).map(plt.scatter, "Apparent Temperature (C)", "Humidity").add_legend()
plt.show()

# %% [markdown]
# #### Observation:
#
# *    There are very few outlier.
# *    Mostly Weather is Clear or Partly Cloudy/Rain in Finland.
# *    Only few days there has a Light Rain or Dry or Dangerously Windy and Partly Cloudy.

# %% [markdown]
# ### Univariate Analysis using PDF:

# %%
# For Apparent Temperature (C)
sns.FacetGrid(df_target, hue="Summary", height=10).map(sns.distplot, "Apparent Temperature (C)").add_legend()
plt.show()

# %%
# For Humidity
sns.FacetGrid(df_target, hue="Summary", height=10).map(sns.distplot, "Humidity").add_legend()
plt.show()

# %% [markdown]
# #### Observation:
#
# *    "Humidity" is better Feature than "Apparent Temperature (C)".

# %% [markdown]
# ### Conclusion:
#
# * H0 is not accepted because there is no change in Humidity from 2006–2016. So, we will accept the H1.
